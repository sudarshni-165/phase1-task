# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\TWERESHER\Downloads\dataset - netflix1.csv")
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.size
# Out:
# 87900

# %%
data.drop_duplicates()
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
data['date_added'] = pd.to_datetime(data['date_added'], infer_datetime_format=True, errors='coerce')
data['date_added'].head(5)
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-22
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]

# %%
data=data[((data['date_added'].dt.year)>=data['release_year'])]
data[data['title'].duplicated()]
# Out:
#      show_id     type   title            director   country date_added  \
# 537    s5965  TV Show   9-Feb           Not Given  Pakistan 2019-03-20
# 4260   s5966    Movie  22-Jul     Paul Greengrass    Norway 2018-10-10
# 4261   s5967    Movie  15-Aug  Swapnaneel Jayakar     India 2019-03-29
#
#       release_year rating  duration                             listed_in
# 537           2018  TV-14  1 Season     International TV Shows, TV Dramas
# 4260          2018      R   144 min                     Dramas, Thrillers
# 4261          2019  TV-14   124 min  Comedies, Dramas, Independent Movies

# %%
data_copy = data.copy()
data_copy.drop_duplicates(['title'], inplace=True)

# %%
data.shape
# Out:
# (8776, 10)

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country date_added  release_year rating   duration  \
# ...
