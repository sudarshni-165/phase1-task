# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarshni-165/phase1-task/blob/main/Turing_Data_Analysis_MCQ_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Turing Data Analysis MCQ Notebook
#
# 🚩DO NOT edit this notebook.
#
# 🚩DO NOT use your own IDE or any online debugger tools.
#
# 🚩DO NOT use the “GENERATE WITH AI” feature, ChatGPT or any other AI tool.
#
# ### **Instructions**
#
# Before you proceed, carefully go through [**these detailed instructions, with examples**](https://docs.google.com/presentation/d/1FwCxHZGwkPdMAKmahBQwPifxaVPEmh7_VHDsQf-8vAg/edit#slide=id.g2c3a4ce1cf3_18_76) to be best prepared for the assessment. Once you are back:
#
# *   Please **clone this Colab notebook using the "Save a copy in Drive" button on the top.**
# *   Rename the file to "\<campus\> - *\<your full name>* - Turing Data Analysis MCQ Notebook.ipynb".
#    *   e.g. "The Chinese University of Hong Kong - Alicia Wong - Turing Data Analysis MCQ Notebook.ipynb".
# *   Once you clone the notebook, make a test update to this text and *refresh to confirm that your progress is being saved*.
# *   We recommend explicitly saving progress and not relying on the auto-save feature.
#
# ### **Submission instructions**
#
# *   Please refer to submission instructions [here](https://docs.google.com/presentation/d/1FwCxHZGwkPdMAKmahBQwPifxaVPEmh7_VHDsQf-8vAg/edit#slide=id.g26d15d6171a_6_1).

# %%
user_fullname = '<Please tell your fullname as for this event>'
user_email = '<Please provide the email you registered on Turing.com>'

# %% [markdown]
# *Please do NOT change this section of the code, but do your imports/changes after this section.*

# %%
import io
import numpy as np
import pandas as pd
import requests
from zipfile import ZipFile

# %%
DATA_FILE = 'https://drive.usercontent.google.com/uc?id=1TMOK9yFDm6nJ2PAC-unBbrG-tR5THJ90&export=download'

# %%
def download_and_load_data_files(url):
  """
  Downloads and loads data files from the given URL, where the data files are expected to be in a zip format.

  Parameters:
  - url (str): The URL from which to download the zip file.

  Returns:
  - dict: A dictionary with file names as keys and dataframes as values, loaded from the zip file.
  """

  def download_data_files(url):
    response = requests.get(DATA_FILE)
    response.raise_for_status()
    return response.content

  def load_data_files(content):
    zip_in_memory = io.BytesIO(content)
    with ZipFile(zip_in_memory, 'r') as zip_ref:
      file_names = zip_ref.namelist()
      dataframes = {}
      for file_name in file_names:
        with zip_ref.open(file_name) as file_content:
          dataframes[file_name] = pd.read_csv(file_content, sep='[,;]', engine='python')
      return dataframes

  zip_file_content = download_data_files(url)
  return load_data_files(zip_file_content)

# %%
contents = download_and_load_data_files(DATA_FILE)

# %%
# Validate the files.
assert ['cardio_alco.csv', 'cardio_base.csv', 'covid_data.csv'] == sorted(contents.keys())
assert type(contents['cardio_alco.csv']) == pd.DataFrame
assert type(contents['cardio_base.csv']) == pd.DataFrame
assert type(contents['covid_data.csv']) == pd.DataFrame
print('You are good to go to start the challenge!')
# Out:
# You are good to go to start the challenge!

# %%
contents['cardio_alco.csv']
# Out:
#           id  alco
# 0         44     0
# 1         45     0
# 2         46     0
# 3         47     0
# 4         49     0
# ...      ...   ...
# 56898  99949     0
# 56899  99950     0
# 56900  99951     0
# 56901  99952     0
# 56902  99954     0
#
# [56903 rows x 2 columns]

# %%
contents['cardio_base.csv']
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  smoke
# 0          0  18393       2     168    62.0    110     80            1      0
# 1          1  20228       1     156    85.0    140     90            3      0
# 2          2  18857       1     165    64.0    130     70            3      0
# 3          3  17623       2     169    82.0    150    100            1      0
# 4          4  17474       1     156    56.0    100     60            1      0
# ...      ...    ...     ...     ...     ...    ...    ...          ...    ...
# 69995  99993  19240       2     168    76.0    120     80            1      1
# 69996  99995  22601       1     158   126.0    140     90            2      0
# 69997  99996  19066       2     183   105.0    180     90            3      0
# 69998  99998  22431       1     163    72.0    135     80            1      0
# 69999  99999  20540       1     170    72.0    120     80            2      0
#
# [70000 rows x 9 columns]

# %%
contents['covid_data.csv']
# Out:
#             location        date  new_cases  new_deaths  population  \
# 0        Afghanistan  2019-12-31          0           0  38928341.0
# 1        Afghanistan  2020-01-01          0           0  38928341.0
# 2        Afghanistan  2020-01-02          0           0  38928341.0
# 3        Afghanistan  2020-01-03          0           0  38928341.0
# 4        Afghanistan  2020-01-04          0           0  38928341.0
# ...              ...         ...        ...         ...         ...
# 23077  International  2020-02-28          0           0         NaN
# 23078  International  2020-02-29          0           2         NaN
# 23079  International  2020-03-01          0           0         NaN
# 23080  International  2020-03-02          0           0         NaN
# 23081  International  2020-03-10         -9           1         NaN
#
#        aged_65_older_percent  gdp_per_capita  hospital_beds_per_thousand
# 0                      2.581        1803.987                         0.5
# ...

# %% [markdown]
# # Start of your code.
#
# Please continue your work here and below.

# %%
# Custom imports
import matplotlib.pyplot as plt
import seaborn

# %%
print('Hello Turing World')
# Out:
# Hello Turing World
